# %%
#First Album
filenamesA1 = ['lyrics_billieeilish_badguy.txt', 'lyrics_billieeilish_xanny.txt','lyrics_billieeilish_youshouldseemeinacrown.txt', 'lyrics_billieeilish_allthegoodgirlsgotohell.txt', 'lyrics_billieeilish_wishyouweregay.txt', 'lyrics_billieeilish_whenthepartysover.txt', 'lyrics_billieeilish_8.txt', 'lyrics_billieeilish_mystrangeaddiction.txt', 'lyrics_billieeilish_buryafriend.txt', 'lyrics_billieeilish_ilomilo.txt', 'lyrics_billieeilish_listenbeforeigo.txt', 'lyrics_billieeilish_iloveyou.txt', 'lyrics_billieeilish_goodbye.txt']
with open('/Users/graceberrien23/Desktop/billie/newBillie.csv', 'w') as outfile:
    for fname in filenamesA1:
        with open(fname) as infile:
            for line in infile:
                outfile.write(line)

# %%
import pandas as pd

# %%
baillieA1 = pd.read_csv('/Users/graceberrien23/Desktop/billie/newBillie.csv', sep = "NaN")

# %%
billieA1
#billieA1.columns
# Out:
#                                                      {
# 0                                     "_type": "song",
# 1                               "annotation_count": 5,
# 2                        "api_path": "/songs/4271772",
# 3                     "artist_names": "Billie Eilish",
# 4    "full_title": "\u200bbad guy by\u00a0Billie\u0...
# ..                                                 ...
# 675                                         "iq": 8271
# 676                                                 },
# 677                         "artist": "Billie Eilish",
# 678  "lyrics": "\u200bgoodbye Lyrics[Intro]\nPlease...
# 679                                                  }
#
# [680 rows x 1 columns]

# %%
billie2A1 = billieA1['{'].str.split(":")

# %%
#billie3A1 = billieA1[billieA1["{"].str.contains("lyrics")]

# %%
#pd.set_option('display.max_rows', 500)
#billie3A1
# Out:
#                                                      {
# 10                         "lyrics_owner_id": 3195745,
# 11                         "lyrics_state": "complete",
# 12                    "lyrics_updated_at": 1645484393,
# 13            "path": "/Billie-eilish-bad-guy-lyrics",
# 34   "url": "https://genius.com/Billie-eilish-bad-g...
# 51   "lyrics": "\u200bbad guy Lyrics[Verse 1]\nWhit...
# 63                         "lyrics_owner_id": 3195745,
# 64                         "lyrics_state": "complete",
# 65                    "lyrics_updated_at": 1631976120,
# 66              "path": "/Billie-eilish-xanny-lyrics",
# 86   "url": "https://genius.com/Billie-eilish-xanny...
# 103  "lyrics": "\u200bxanny Lyrics[Verse 1]\nWhat i...
# 115                        "lyrics_owner_id": 3958233,
# 116                        "lyrics_state": "complete",
# 117                   "lyrics_updated_at": 1611688626,
# 118  "path": "/Billie-eilish-you-should-see-me-in-a...
# 138  "url": "https://genius.com/Billie-eilish-you-s...
# 155  "lyrics": "\u200byou should see me in a crown ...
# 167                        "lyrics_owner_id": 3195745,
# 168                        "lyrics_state": "complete",
# 169                   "lyrics_updated_at": 1646190955,
# 170  "path": "/Billie-eilish-all-the-good-girls-go-...
# 190  "url": "https://genius.com/Billie-eilish-all-t...
# 207  "lyrics": "\u200ball the good girls go to hell...
# 219                        "lyrics_owner_id": 4104782,
# 220                        "lyrics_state": "complete",
# 221                   "lyrics_updated_at": 1639081930,
# 222  "path": "/Billie-eilish-wish-you-were-gay-lyri...
# 243  "url": "https://genius.com/Billie-eilish-wish-...
# 260  "lyrics": "\u200bwish you were gay Lyrics[Vers...
# 272                        "lyrics_owner_id": 5614516,
# 273                        "lyrics_state": "complete",
# 274                   "lyrics_updated_at": 1629578622,
# 275  "path": "/Billie-eilish-when-the-partys-over-l...
# 296  "url": "https://genius.com/Billie-eilish-when-...
# 313  "lyrics": "\u200bwhen the party\u2019s over Ly...
# 325                        "lyrics_owner_id": 3195745,
# 326                        "lyrics_state": "complete",
# 327                   "lyrics_updated_at": 1584462078,
# 328                 "path": "/Billie-eilish-8-lyrics",
# 348  "url": "https://genius.com/Billie-eilish-8-lyr...
# 365  "lyrics": "8 Lyrics[Verse 1]\nWait a minute, l...
# 377                        "lyrics_owner_id": 3195745,
# 378                        "lyrics_state": "complete",
# 379                   "lyrics_updated_at": 1656893779,
# 380  "path": "/Billie-eilish-my-strange-addiction-l...
# 400  "url": "https://genius.com/Billie-eilish-my-st...
# 417  "lyrics": "\u200bmy strange addiction Lyrics[I...
# 429                        "lyrics_owner_id": 3355833,
# 430                        "lyrics_state": "complete",
# 431                   "lyrics_updated_at": 1610910635,
# 432     "path": "/Billie-eilish-bury-a-friend-lyrics",
# 452  "url": "https://genius.com/Billie-eilish-bury-...
# 469  "lyrics": "\u200bbury a friend Lyrics[Intro: M...
# 481                        "lyrics_owner_id": 3195745,
# 482                        "lyrics_state": "complete",
# 483                   "lyrics_updated_at": 1649817450,
# 484           "path": "/Billie-eilish-ilomilo-lyrics",
# 504  "url": "https://genius.com/Billie-eilish-ilomi...
# 521  "lyrics": "\u200bilomilo Lyrics[Verse 1]\nTold...
# 533                        "lyrics_owner_id": 1582243,
# 534                        "lyrics_state": "complete",
# 535                   "lyrics_updated_at": 1650547633,
# 536  "path": "/Billie-eilish-listen-before-i-go-lyr...
# 557  "url": "https://genius.com/Billie-eilish-liste...
# 574  "lyrics": "\u200blisten before i go Lyrics[Ver...
# 586                        "lyrics_owner_id": 3195745,
# 587                        "lyrics_state": "complete",
# 588                   "lyrics_updated_at": 1651784160,
# 589        "path": "/Billie-eilish-i-love-you-lyrics",
# 609  "url": "https://genius.com/Billie-eilish-i-lov...
# 626  "lyrics": "\u200bi love you Lyrics[Verse 1]\nI...
# 638                        "lyrics_owner_id": 3195745,
# 639                        "lyrics_state": "complete",
# 640                   "lyrics_updated_at": 1573759418,
# 641           "path": "/Billie-eilish-goodbye-lyrics",
# 661  "url": "https://genius.com/Billie-eilish-goodb...
# 678  "lyrics": "\u200bgoodbye Lyrics[Intro]\nPlease...

# %%
billie4A1 = billie3A1['{'].str.split(":")

# %%
#lyricsA1 = billie4A1.iloc[5] + billie4A1.iloc[11] + billie4A1.iloc[17] + billie4A1.iloc[23] + billie4A1.iloc[29] + billie4A1.iloc[35] + billie4A1.iloc[41]

#for i in length(billie4A1):
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/37/vz0xbxwx689_2c02hq67dp540000gn/T/ipykernel_24605/3132305700.py in <module>
#       3 #for i in length(billie4A1):
#       4
# ----> 5 billie4A1.length()
#       6
#       7
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 
-da-da-da-da\\nDa-da-da-da-da-da-da\\nOh, hmm, hmm\\nYou might also like[Verse 2]\\nYou said, \\"Don\'t treat me badly\\"\\nBut you said it so sadly\\nSo I did the best I could\\nNot thinkin\' you would have left me gladly\\nI know you\'re not sorry\\nWhy should you be?\\n\'Cause who am I to be in love\\nWhen your love never is for me?\\nMe\\n\\n[Refrain]\\nDa-da-da-da-da-da-da (Hmm)\\nDa-da-da-da-da-da-da (Hmm, hmm, hmm, hmm)\\nOh, hmm, hmm\\n\\n[Chorus]\\nSo I think I better go\\nI never really know how to please you\\nYou\'re lookin\' at me like I\'m see-through\\nI guess I\'m gonna go\\nI just never know how you feel\\nDo you even feel anything?67Embed"']

# %%
df = pd.DataFrame(billie4A1)

# %%
df.to_excel("/Users/graceberrien23/Desktop/billie/A1Billie.xlsx")

# %%
#pip install PyLyrics
# Out:
# Collecting PyLyrics
#   Downloading PyLyrics-1.1.0.zip (7.0 kB)
# Requirement already satisfied: beautifulsoup4 in ./opt/anaconda3/lib/python3.9/site-packages (from PyLyrics) (4.10.0)
# Requirement already satisfied: requests in ./opt/anaconda3/lib/python3.9/site-packages (from PyLyrics) (2.26.0)
# Requirement already satisfied: soupsieve>1.2 in ./opt/anaconda3/lib/python3.9/site-packages (from beautifulsoup4->PyLyrics) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in ./opt/anaconda3/lib/python3.9/site-packages (from requests->PyLyrics) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in ./opt/anaconda3/lib/python3.9/site-packages (from requests->PyLyrics) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in ./opt/anaconda3/lib/python3.9/site-packages (from requests->PyLyrics) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in ./opt/anaconda3/lib/python3.9/site-packages (from requests->PyLyrics) (3.2)
# Building wheels for collected packages: PyLyrics
#   Building wheel for PyLyrics (setup.py) ... done
#   Created wheel for PyLyrics: filename=PyLyrics-1.1.0-py3-none-any.whl size=3578 sha256=2a6071d9f3bc7bbae18e8bf5326e48b8d357e1f872b49da555fc2320dabc9dcd
#   Stored in directory: /Users/graceberrien23/Library/Caches/pip/wheels/43/65/e1/1ba0f0bf48275b1b985cbc5ff6c12dfb30bc7bca95777d2fe2
# Successfully built PyLyrics
# Installing collected packages: PyLyrics
# Successfully installed PyLyrics-1.1.0
# Note: you may need to restart the kernel to use updated packages.

# %%
#Second Album
filenamesA2 = ['lyrics_billieeilish_gettingolder.txt', 'lyrics_billieeilish_ididntchangemynumber.txt','lyrics_billieeilish_billiebossanova.txt', 'lyrics_billieeilish_myfuture.txt', 'lyrics_billieeilish_oxytocin.txt', 'lyrics_billieeilish_goldwing.txt', 'lyrics_billieeilish_lostcause.txt', 'lyrics_billieeilish_halleyscomet.txt', 'lyrics_billieeilish_notmyresponsibility.txt', 'lyrics_billieeilish_overheated.txt', 'lyrics_billieeilish_everybodydies.txt', 'lyrics_billieeilish_yourpower.txt', 'lyrics_billieeilish_nda.txt', 'lyrics_billieeilish_thereforeiam.txt', 'lyrics_billieeilish_happierthanever.txt', 'lyrics_billieeilish_malefantasy.txt']
with open('/Users/graceberrien23/Desktop/billie/BillieA2.csv', 'w') as outfile:
    for fname in filenamesA2:
        with open(fname) as infile:
            for line in infile:
                outfile.write(line)

# %%
billieA2 = pd.read_csv('/Users/graceberrien23/Desktop/billie/BillieA2.csv', sep = "NaN")

# %%
billie2A2 = billieA2['{'].str.split(":")

# %%
df2 = pd.DataFrame(billie2A2)

# %%
df2.to_excel("/Users/graceberrien23/Desktop/billie/A2Billie.xlsx")
